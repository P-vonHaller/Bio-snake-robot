# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        
        # 21 input image channel, 21 output channels, 5x5 square convolution kernel
        self.conv1 = nn.Conv3d(21, 21, kernel_size=(5, 5, 1), stride=1)

    def forward(self, x):
        x = F.max_pool3d(F.relu(self.conv1(x)), 1)
        return x

    def num_flat_features(self, x):
        size = x.size()[1:]  # all dimensions except the batch dimension
        num_features = 1
        for s in size:
            num_features *= s
        return num_features


net = Net()
print(net)
print(net.conv1.weight.data.size())
# Out:
# Net(
#   (conv1): Conv3d(21, 21, kernel_size=(5, 5, 1), stride=(1, 1, 1))
# )
# torch.Size([21, 21, 5, 5, 1])

# %%
params = list(net.conv1.parameters())
print(params[0].size())  # conv1's .weight
print(params[0])
# Out:
# 2
# torch.Size([21, 21, 5, 5, 3])
# Parameter containing:
# tensor([[[[[-1.1179e-02,  1.1250e-02,  1.4604e-02],
#            [-1.3181e-02, -5.7027e-03,  1.8401e-02],
#            [ 6.0131e-03, -3.0401e-03, -5.0965e-03],
#            [ 1.8724e-02,  2.1170e-02,  2.4437e-02],
#            [ 1.9689e-02, -3.9360e-03,  9.6112e-03]],
#
#           [[-1.5173e-02, -4.7855e-03, -2.0322e-02],
#            [ 1.6047e-03, -1.9804e-02, -1.9260e-02],
#            [-1.3075e-02, -2.4020e-02,  1.6804e-03],
#            [-1.2792e-02,  2.1428e-02,  7.1860e-03],
#            [ 4.7828e-03, -6.2975e-03,  2.0833e-02]],
#
#           [[-2.3656e-02, -1.3803e-02, -8.2166e-03],
#            [-5.3832e-04, -4.8629e-03, -1.4439e-02],
#            [-9.3742e-03, -2.3144e-02,  2.2718e-02],
#            [ 1.2150e-02, -3.6407e-04,  1.4969e-03],
#            [ 2.4664e-02, -1.7345e-02,  2.4759e-03]],
#
#           [[-3.4189e-03, -1.3659e-02,  1.0256e-02],
#            [ 1.9765e-02,  1.9662e-02, -6.9603e-03],
# ...

# %%
input = torch.zeros(21, 21, 32, 32, 3)
out = net(input)
print(len(out))
print(out.size())

test = torch.randn(3, 3, 3)
print(test)
print(test[0][0][1])
# Out:
# 21
# torch.Size([21, 21, 28, 28, 1])
# tensor([[[ 1.1401, -0.8579, -1.9418],
#          [ 2.3377,  0.7222, -0.7719],
#          [-0.6079,  0.6658,  0.2678]],
#
#         [[ 0.8969,  0.6106, -0.1454],
#          [-0.3914,  0.0151, -1.3154],
#          [-1.3848, -0.7778, -0.9535]],
#
#         [[-1.5169, -0.3430, -0.2059],
#          [ 0.4271,  0.6055,  0.2264],
#          [ 1.5485, -1.9382,  1.2172]]])
# tensor(-0.8579)

# %%
def calcColorDistance(i, j):
    colorWeight = 0.5
    distance = colorWeight * (i[0]-j[0])^2+(i[1]-j[1])^2+(i[2]-j[2])^2
    #distance += spatialWeight * ((i.positionX - j.positionX)^2 + (i.positionY - j.positionY)^2)/2 #unfinished
    return distance
# Out:
#   File "<ipython-input-7-d0c36d84f3c2>", line 4
#     distance = colorWeight * #binmirnichtsicher
#                                                ^
# SyntaxError: invalid syntax

# %%
def initializeFilters(image):
    filters = torch.zeros(21, 21, 5, 5, 1)
    print(filters.size())
    filterLen = 5
    filterWidth = 5
    middle = ceil(filterLen/2)
    #for imageY in range image.height
    #    for imageX in range image.width
    #        for y in range filterLen:
    #            for x in range filterWidth:
    #                if !((imageX + (x-middle)) < 0 || (imageX + (x-middle)) > imageWidth || (imageY + (y-middle)) < 0 || (imageY + (Y-middle)) > imageHeight)
    #                    filters[imageX][imageY][x][y][0] += calcColorDistance(image[imageX][imageY], image[imageX + (x-middle)][imageY + (y-middle)])
    #                    filters[imageX][imageY][x][y][0] += 
    #                else
    #                    filters[imageX][imageY][x][y][0] = 0
